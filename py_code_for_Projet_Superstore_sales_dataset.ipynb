# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Data manipulation

# %%
df = pd.read_csv("C:/Users/user/Documents/GitHub/testpy/train.csv")
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 5          6  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 6          7  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 7          8  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 8          9  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 9         10  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 10        11  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 11        12  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 12        13  CA-2018-114412  15/04/2018  20/04/2018  Standard Class
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
# Row ID           9800 non-null int64
# Order ID         9800 non-null object
# Order Date       9800 non-null object
# Ship Date        9800 non-null object
# Ship Mode        9800 non-null object
# Customer ID      9800 non-null object
# Customer Name    9800 non-null object
# Segment          9800 non-null object
# Country          9800 non-null object
# City             9800 non-null object
# State            9800 non-null object
# Postal Code      9789 non-null float64
# Region           9800 non-null object
# Product ID       9800 non-null object
# Category         9800 non-null object
# Sub-Category     9800 non-null object
# Product Name     9800 non-null object
# Sales            9800 non-null float64
# dtypes: float64(2), int64(1), object(15)
# memory usage: 1.3+ MB

# %%
# Here we display only the 'corporate' segment with this filter
segment_corporate = df[df['Segment'] == 'Corporate']
segment_corporate
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 21        22  CA-2017-137330  09/12/2017  13/12/2017  Standard Class
# 22        23  CA-2017-137330  09/12/2017  13/12/2017  Standard Class
# 35        36  CA-2017-117590  08/12/2017  10/12/2017     First Class
# 36        37  CA-2017-117590  08/12/2017  10/12/2017     First Class
# 41        42  CA-2018-120999  10/09/2018  15/09/2018  Standard Class
# 42        43  CA-2017-101343  17/07/2017  22/07/2017  Standard Class
# 43        44  CA-2018-139619  19/09/2018  23/09/2018  Standard Class
# 44        45  CA-2017-118255  11/03/2017  13/03/2017     First Class
# 45        46  CA-2017-118255  11/03/2017  13/03/2017     First Class
# 53        54  CA-2017-105816  11/12/2017  17/12/2017  Standard Class
# 54        55  CA-2017-105816  11/12/2017  17/12/2017  Standard Class
# 67        68  CA-2015-106376  05/12/2015  10/12/2015  Standard Class
# ...

# %%
# here we display the ten first rows of these four columns
s = df[['Country','State','City','Sales']]
s.head(10)
# Out:
#          Country       State             City     Sales
# 0  United States    Kentucky        Henderson  261.9600
# 1  United States    Kentucky        Henderson  731.9400
# 2  United States  California      Los Angeles   14.6200
# 3  United States     Florida  Fort Lauderdale  957.5775
# 4  United States     Florida  Fort Lauderdale   22.3680
# 5  United States  California      Los Angeles   48.8600
# 6  United States  California      Los Angeles    7.2800
# 7  United States  California      Los Angeles  907.1520
# 8  United States  California      Los Angeles   18.5040
# 9  United States  California      Los Angeles  114.9000

# %%
# Calculating of number of null values : Compter le nbre de cellules vide
postal_null = df['Postal Code'].isnull().sum()
postal_null
# Out:
# 11

# %%
# Remplir les cellules vides par une valeur ici on utilise 0 : Filling empty cells with a value
df['Postal Code'].fillna(0, inplace = True)
df.head(5)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
# changing a float to integer : changer le type d'une colonne

# loop a dataframe : for x in df.index :
                                     #if df.loc[x, 'Duration'] > 120 :
                                                #df.loc[x, 'Duration'] = 60
df['Postal Code'].fillna(0, inplace = True)

df['Postal Code'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
# Row ID           9800 non-null int64
# Order ID         9800 non-null object
# Order Date       9800 non-null object
# Ship Date        9800 non-null object
# Ship Mode        9800 non-null object
# Customer ID      9800 non-null object
# Customer Name    9800 non-null object
# Segment          9800 non-null object
# Country          9800 non-null object
# City             9800 non-null object
# State            9800 non-null object
# Postal Code      9800 non-null float64
# Region           9800 non-null object
# Product ID       9800 non-null object
# Category         9800 non-null object
# Sub-Category     9800 non-null object
# Product Name     9800 non-null object
# Sales            9800 non-null float64
# dtypes: float64(2), int64(1), object(15)
# memory usage: 1.3+ MB

# %%
#Ici on affiche la moyenne des prix en fonction des ville
moy_price_per_city  = df.groupby('City').agg({'Sales': 'mean'}).reset_index()
print(moy_price_per_city)
# Out:
#                   City       Sales
# 0             Aberdeen   25.500000
# 1              Abilene    1.392000
# 2                Akron  136.212200
# 3          Albuquerque  158.582857
# 4           Alexandria  344.973125
# 5                Allen   72.551500
# 6            Allentown  121.893143
# 7              Altoona   10.225500
# 8             Amarillo  377.306280
# 9              Anaheim  294.765684
# 10             Andover  108.962500
# 11           Ann Arbor  177.854600
# 12             Antioch   19.440000
# 13              Apopka  129.222000
# 14        Apple Valley  228.113444
# 15            Appleton  835.655000
# 16           Arlington  336.908867
# 17   Arlington Heights   14.112000
# 18              Arvada  125.850000
# 19           Asheville  210.768000
# 20              Athens  239.120000
# 21             Atlanta  440.970256
# 22       Atlantic City   23.360000
# 23              Auburn  131.465333
# 24              Aurora  171.418794
# 25              Austin  155.332872
# ...

# %%
moy_price_per_states = df.groupby('State').agg({'Sales': 'mean'})
print(moy_price_per_states)
# Out:
#                             Sales
# State
# Alabama                319.846557
# Arizona                158.173350
# Arkansas               194.635500
# California             229.345562
# Colorado               177.886022
# Connecticut            163.223866
# Delaware               293.795688
# District of Columbia   286.502000
# Florida                237.095260
# Georgia                272.424350
# Idaho                  208.689810
# Illinois               164.050760
# Indiana                360.877037
# Iowa                   170.906154
# Kansas                 121.429583
# Kentucky               266.119635
# Louisiana              222.708537
# Maine                  158.816250
# Maryland               225.766886
# Massachusetts          212.106919
# Michigan               300.933099
# Minnesota              335.541011
# Mississippi            203.232830
# Missouri               336.441667
# Montana                372.623467
# Nebraska               196.445526
# ...

# %%
group = df.groupby(['Country', 'City', 'State']).agg({'Sales': 'mean'})
print(group)
# Out:
#                                                            Sales
# Country       City              State
# United States Aberdeen          South Dakota           25.500000
#               Abilene           Texas                   1.392000
#               Akron             Ohio                  136.212200
#               Albuquerque       New Mexico            158.582857
#               Alexandria        Virginia              344.973125
#               Allen             Texas                  72.551500
#               Allentown         Pennsylvania          121.893143
#               Altoona           Pennsylvania           10.225500
#               Amarillo          Texas                 377.306280
#               Anaheim           California            294.765684
#               Andover           Massachusetts         108.962500
#               Ann Arbor         Michigan              177.854600
#               Antioch           California             19.440000
# ...

# %%
# ici on a sommé les ventes par ville
sum_sales = df.groupby(['State']).agg({'Sales': 'sum'})
print(sum_sales)
# Out:
#                             Sales
# State
# Alabama                19510.6400
# Arizona                35272.6570
# Arkansas               11678.1300
# California            446306.4635
# Colorado               31841.5980
# Connecticut            13384.3570
# Delaware               27322.9990
# District of Columbia    2865.0200
# Florida                88436.5320
# Georgia                48219.1100
# Idaho                   4382.4860
# Illinois               79236.5170
# Indiana                48718.4000
# Iowa                    4443.5600
# Kansas                  2914.3100
# Kentucky               36458.3900
# Louisiana               9131.0500
# Maine                   1270.5300
# Maryland               23705.5230
# Massachusetts          28634.4340
# Michigan               76136.0740
# Minnesota              29863.1500
# Mississippi            10771.3400
# Missouri               22205.1500
# Montana                 5589.3520
# Nebraska                7464.9300
# ...

# %%
# ici on va calculer la moyenne des ventes dans la ville de washington 
mean_sales_washington = df.groupby(df['State']== 'washington').agg({'Sales': 'mean'})
print(mean_sales_washington)
# Out:
#             Sales
# State
# False  230.769059

# %%
# Ici on va filtrer notre dataset pour qu'il nous retourne seulement les éléments du 'Nevada'
State_Nevada = df[df['State'] == 'Nevada']
State_Nevada
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 394      395  CA-2018-102946  30/06/2018  05/07/2018  Standard Class
# 1152    1153  CA-2017-160395  31/12/2017  06/01/2018  Standard Class
# 1153    1154  CA-2017-160395  31/12/2017  06/01/2018  Standard Class
# 1516    1517  CA-2018-148446  10/12/2018  14/12/2018    Second Class
# 1671    1672  CA-2017-107615  22/03/2017  25/03/2017     First Class
# 1866    1867  CA-2018-118857  15/04/2018  18/04/2018     First Class
# 2418    2419  CA-2017-107202  21/05/2017  28/05/2017  Standard Class
# 3368    3369  CA-2016-115511  21/11/2016  25/11/2016  Standard Class
# 3369    3370  CA-2016-115511  21/11/2016  25/11/2016  Standard Class
# 3837    3838  CA-2015-126760  26/07/2015  02/08/2015  Standard Class
# 3838    3839  CA-2015-126760  26/07/2015  02/08/2015  Standard Class
# 3839    3840  CA-2015-126760  26/07/2015  02/08/2015  Standard Class
# 3840    3841  CA-2015-126760  26/07/2015  02/08/2015  Standard Class
# ...

# %%
# Ici on a affiché les données minimales de ventes dans tous les villes du Nevada
moneva = State_Nevada.groupby(['City']).agg({'Sales': 'min'})
print("Les valuers minimales en fonction des villes du Nevada sont:")
print(moneva)
# Out:
# Les valuers minimales en fonction des villes du Nevada sont:
#                   Sales
# City
# Henderson         5.728
# Las Vegas         8.288
# North Las Vegas   6.480
# Reno              3.640
# Sparks           79.360

# %%
# Ici on a une vue statistique sur notre dataset
df.describe()
# Out:
#             Row ID   Postal Code         Sales
# count  9800.000000   9800.000000   9800.000000
# mean   4900.500000  55211.280918    230.769059
# std    2829.160653  32076.677954    626.651875
# min       1.000000      0.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  57551.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %%
# Convertir le type de colonne dans un Datasets
df[['Row ID', 'Postal Code']] = df[['Row ID', 'Postal Code']].astype(str)
print(df.dtypes)
# Out:
# Row ID            object
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code       object
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# dtype: object

# %% [markdown]
# # DATA CLEANING
# ## CHECKING FOR DUPLICATE

# %%
# Using conditional statements

print(df.duplicated())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 9770    False
# 9771    False
# 9772    False
# 9773    False
# 9774    False
# 9775    False
# 9776    False
# 9777    False
# 9778    False
# 9779    False
# 9780    False
# 9781    False
# 9782    False
# 9783    False
# 9784    False
# 9785    False
# 9786    False
# 9787    False
# 9788    False
# 9789    False
# 9790    False
# 9791    False
# 9792    False
# 9793    False
# 9794    False
# 9795    False
# 9796    False
# 9797    False
# 9798    False
# 9799    False
# ...

# %%
# supprime les colonnes dupliquées en modifiant le fichier d'origine 
df.drop_duplicates(inplace = True)
df
# Out:
#      Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0         1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1         2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2         3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3         4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4         5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 5         6  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 6         7  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 7         8  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 8         9  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 9        10  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 10       11  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 11       12  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 12       13  CA-2018-114412  15/04/2018  20/04/2018  Standard Class
# ...

# %%
# types of customers : on veut voir les différents éléments dans une colonne

types_of_customers = df['Segment'].unique()
print(types_of_customers)
# Out:
# ['Consumer' 'Corporate' 'Home Office']

# %%
# count number of customers in each segment

number_of_customers = df['Segment'].value_counts().reset_index()
print(number_of_customers)
# Out:
#          index  Segment
# 0     Consumer     5101
# 1    Corporate     2953
# 2  Home Office     1746

# %%
# ici on change de nom à nos colonnes 'index' et 'segment' 
Total_of_customers = number_of_customers.rename(columns = {'index':'Customer Type', 'Segment':'Total Customers'})
print(Total_of_customers)
# Out:
#   Customer Type  Total Customers
# 0      Consumer             5101
# 1     Corporate             2953
# 2   Home Office             1746

# %%
# Avec la fction unique() on renvoi de manière unique les éléments d'une colonne
types_of_states = df['State'].unique()
types_of_states
# Out:
# array(['Kentucky', 'California', 'Florida', 'North Carolina',
#        'Washington', 'Texas', 'Wisconsin', 'Utah', 'Nebraska',
#        'Pennsylvania', 'Illinois', 'Minnesota', 'Michigan', 'Delaware',
#        'Indiana', 'New York', 'Arizona', 'Virginia', 'Tennessee',
#        'Alabama', 'South Carolina', 'Oregon', 'Colorado', 'Iowa', 'Ohio',
#        'Missouri', 'Oklahoma', 'New Mexico', 'Louisiana', 'Connecticut',
#        'New Jersey', 'Massachusetts', 'Georgia', 'Nevada', 'Rhode Island',
#        'Mississippi', 'Arkansas', 'Montana', 'New Hampshire', 'Maryland',
#        'District of Columbia', 'Kansas', 'Vermont', 'Maine',
#        'South Dakota', 'Idaho', 'North Dakota', 'Wyoming',
#        'West Virginia'], dtype=object)

# %% [markdown]
# #### Fix the format of date

# %%
# On utilise la boucle 'for' pour éviter d'utiliser le datetime() +sieurs fois

#df['Ship Date'] = pd.to_datetime(df['Ship Date'])
#df['Order Date'] = pd.to_datetime(df['Order Date'])
date_columns = ['Ship Date', 'Order Date']

for x in date_columns:
    df[x] = pd.to_datetime(df[x])
    
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
# Row ID           9800 non-null object
# Order ID         9800 non-null object
# Order Date       9800 non-null datetime64[ns]
# Ship Date        9800 non-null datetime64[ns]
# Ship Mode        9800 non-null object
# Customer ID      9800 non-null object
# Customer Name    9800 non-null object
# Segment          9800 non-null object
# Country          9800 non-null object
# City             9800 non-null object
# State            9800 non-null object
# Postal Code      9800 non-null object
# Region           9800 non-null object
# Product ID       9800 non-null object
# Category         9800 non-null object
# Sub-Category     9800 non-null object
# Product Name     9800 non-null object
# Sales            9800 non-null float64
# dtypes: datetime64[ns](2), float64(1), object(15)
# memory usage: 1.4+ MB

# %%
# we created a dataframe with the orders who are equals or greater than year 2018
dat = df[df['Order Date'] >= '2018']
dat
# Out:
#      Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 12       13  CA-2018-114412 2018-04-15 2018-04-20  Standard Class    AA-10480
# 23       24  US-2018-156909 2018-07-16 2018-07-18    Second Class    SF-20065
# 34       35  CA-2018-107727 2018-10-19 2018-10-23    Second Class    MA-17560
# 41       42  CA-2018-120999 2018-10-09 2018-09-15  Standard Class    LC-16930
# 43       44  CA-2018-139619 2018-09-19 2018-09-23  Standard Class    ES-14080
# 71       72  CA-2018-114440 2018-09-14 2018-09-17    Second Class    TB-21520
# 75       76  US-2018-118038 2018-09-12 2018-11-12     First Class    KB-16600
# 76       77  US-2018-118038 2018-09-12 2018-11-12     First Class    KB-16600
# 77       78  US-2018-118038 2018-09-12 2018-11-12     First Class    KB-16600
# 84       85  US-2018-119662 2018-11-13 2018-11-16     First Class    CS-12400
# 85       86  CA-2018-140088 2018-05-28 2018-05-30    Second Class    PO-18865
# ...

# %%
# trier par ordre croissant 
dat = dat.sort_values(by='Order Date')
#dat = dat.sort_values(by=['Order Date', 'Ship Date']) pour trier sur +de 2 colonnes
dat
# Out:
#      Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 8070   8071  CA-2018-151750 2018-01-01 2018-05-01  Standard Class    JM-15250
# 4009   4010  CA-2018-144463 2018-01-01 2018-05-01  Standard Class    SC-20725
# 848     849  CA-2018-107503 2018-01-01 2018-06-01  Standard Class    GA-14725
# 8075   8076  CA-2018-151750 2018-01-01 2018-05-01  Standard Class    JM-15250
# 8074   8075  CA-2018-151750 2018-01-01 2018-05-01  Standard Class    JM-15250
# 6682   6683  CA-2018-154466 2018-01-01 2018-02-01     First Class    DP-13390
# 8073   8074  CA-2018-151750 2018-01-01 2018-05-01  Standard Class    JM-15250
# 8069   8070  CA-2018-151750 2018-01-01 2018-05-01  Standard Class    JM-15250
# 8072   8073  CA-2018-151750 2018-01-01 2018-05-01  Standard Class    JM-15250
# 8071   8072  CA-2018-151750 2018-01-01 2018-05-01  Standard Class    JM-15250
# 2616   2617  CA-2018-147942 2018-01-04 2018-05-04  Standard Class    MS-17365
# ...

# %%
# trier par ordre décroissant 
dat = dat.sort_values(by='Order Date', ascending=False)
#dat = dat.sort_values(by=['Order Date', 'Ship Date'], ascending=[False, False]) pour trier sur +de 2 colonnes
dat
# Out:
#      Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 645     646  CA-2018-126221 2018-12-30 2019-05-01  Standard Class    CC-12430
# 908     909  CA-2018-143259 2018-12-30 2019-03-01  Standard Class    PO-18865
# 1296   1297  CA-2018-115427 2018-12-30 2019-03-01  Standard Class    EB-13975
# 1297   1298  CA-2018-115427 2018-12-30 2019-03-01  Standard Class    EB-13975
# 906     907  CA-2018-143259 2018-12-30 2019-03-01  Standard Class    PO-18865
# 5091   5092  CA-2018-156720 2018-12-30 2019-03-01  Standard Class    JM-15580
# 907     908  CA-2018-143259 2018-12-30 2019-03-01  Standard Class    PO-18865
# 1877   1878  CA-2018-118885 2018-12-29 2019-02-01  Standard Class    JG-15160
# 4239   4240  CA-2018-158673 2018-12-29 2019-04-01  Standard Class    KB-16600
# 7635   7636  US-2018-158526 2018-12-29 2019-01-01    Second Class    KH-16360
# 7636   7637  US-2018-158526 2018-12-29 2019-01-01    Second Class    KH-16360
# ...

# %%
# ici on affiche les années de facons distinct sachant que order date est sur format yyyy-mm-dd
year = df['Order Date'].dt.year.unique()
print(year)
# Out:
# [2017 2016 2015 2018]

# %% [markdown]
# # Plotting : Customers and sales

# %%
number_of_customer = df['Segment'].value_counts().reset_index()
number_of_customer = number_of_customer.rename(columns={'index': 'Segment', 'Segment':'Total_Customers'})
print(number_of_customer.sort_values(by='Segment', ascending=False).reset_index(drop=True))

# plotting a pie chart 
plt.pie(number_of_customer['Total_Customers'], labels = number_of_customer['Segment'], autopct = '%1.1f%%')

# Set pie chart labels
plt.title('Distribution of Customers')

plt.show()
#Dans cet exemple, autopct='%1.1f%%' spécifie que les étiquettes de pourcentage 
#doivent être formatées avec une décimale et un pourcentage.
# Out:
#        Segment  Total_Customers
# 0  Home Office             1746
# 1    Corporate             2953
# 2     Consumer             5101

# %%
# On veut avoir la somme des ventes par type de segment : 1ière méthode
sales_per_category = df.groupby('Segment').agg({'Sales':'sum'})
sales_per_category
# Out:
#                     Sales
# Segment
# Consumer     1.148061e+06
# Corporate    6.884941e+05
# Home Office  4.249822e+05

# %%
# On veut avoir la somme des ventes par type de segment : 2nd méthode
sales_per_category = df.groupby('Segment')['Sales'].sum().reset_index()
sales_per_category
# Out:
#        Segment         Sales
# 0     Consumer  1.148061e+06
# 1    Corporate  6.884941e+05
# 2  Home Office  4.249822e+05

# %%
# Changeons les noms des deux colonnes
new_sales_per_category = sales_per_category.rename(columns = {'Segment':'Customer Type', 'Sales':'Total Sales'})
print(new_sales_per_category)
# Out:
#   Customer Type   Total Sales
# 0      Consumer  1.148061e+06
# 1     Corporate  6.884941e+05
# 2   Home Office  4.249822e+05

# %%
# plotting a pie chart 
plt.pie(new_sales_per_category['Total Sales'], labels = new_sales_per_category['Customer Type'], autopct = '%1.1f%%')

# Set pie chart labels
plt.title('Sales per Customer category')

plt.show()

# %%
# diagramme à barres

plt.bar(new_sales_per_category['Customer Type'], new_sales_per_category['Total Sales'])

# Label
plt.title('sales per customer category')
plt.xlabel('Customer type')
plt.ylabel('Total Sales')

plt.show()

# %% [markdown]
# # Customer Loyalty

# %%
# Customer Loyalty : fidélité du consommateur
df.head(3)
# Out:
#    Row ID        Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017  Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017  Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017  Second Class    DV-13045
#
#      Customer Name    Segment        Country         City       State  \
# 0      Claire Gute   Consumer  United States    Henderson    Kentucky
# 1      Claire Gute   Consumer  United States    Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  California
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# 0      42420.0  South  FUR-BO-10001798        Furniture    Bookcases
# 1      42420.0  South  FUR-CH-10000454        Furniture       Chairs
# 2      90036.0   West  OFF-LA-10000240  Office Supplies       Labels
#
#                                         Product Name   Sales
# ...

# %%
#Group data according to: Customer ID, Customer Name, Segment and calculate frequence of their orders
customer_order_freq = df.groupby(['Customer ID', 'Customer Name', 'Segment'])['Order ID'].count().reset_index()

# renommons la colonne Order ID
customer_order_freq = customer_order_freq.rename(columns = {'Order ID': 'Total Orders'})
# ou bien : customer_order_freq.rename(columns = {'Order ID': 'Total Orders'}, inplace=True)

# identifier les clients réguliers : identify repeat customers
repeat_customers = customer_order_freq[customer_order_freq['Total Orders'] >= 1] # un filtre

#sort repeat customer in descending order
sorted_repeat_customers = repeat_customers.sort_values(by='Total Orders', ascending=False)

print(sorted_repeat_customers.head(10).reset_index(drop=True))

# reset_index(drop=True) va renitialiser les index et supprimer les anciens index
# Out:
#   Customer ID        Customer Name      Segment  Total Orders
# 0    WB-21850        William Brown     Consumer            35
# 1    PP-18955           Paul Prost  Home Office            34
# 2    MA-17560         Matt Abelman  Home Office            34
# 3    JL-15835             John Lee     Consumer            33
# 4    CK-12205  Chloris Kastensmidt     Consumer            32
# 5    SV-20365          Seth Vernon     Consumer            32
# 6    JD-15895     Jonathan Doherty    Corporate            32
# 7    AP-10915       Arthur Prichep     Consumer            31
# 8    ZC-21910     Zuschuss Carroll     Consumer            31
# 9    EP-13915           Emily Phan     Consumer            31

# %%
customer_sales = df.groupby(['Customer ID', 'Customer Name'])['Sales'].sum().reset_index()

#top_spender = customer_sales.sort_values(['Sales'], ascending=False) : même code ke celui du bas
top_spender = customer_sales.sort_values(by='Sales', ascending=False)
#print(customer_sales.head(10))
print(top_spender.head(10).reset_index(drop=True))
# Out:
#   Customer ID       Customer Name      Sales
# 0    SM-20320         Sean Miller  25043.050
# 1    TC-20980        Tamara Chand  19052.218
# 2    RB-19360        Raymond Buch  15117.339
# 3    TA-21385        Tom Ashbrook  14595.620
# 4    AB-10105       Adrian Barton  14473.571
# 5    KL-16645        Ken Lonsdale  14175.229
# 6    SC-20095        Sanjit Chand  14142.334
# 7    HL-15040        Hunter Lopez  12873.298
# 8    SE-20110        Sanjit Engle  12209.438
# 9    CC-12370  Christopher Conant  12129.072

# %% [markdown]
# # MODE OF SHIPPING

# %%
# Mode d'expédition
shipping_mode = df['Ship Mode'].unique()
print(shipping_mode)
# Out:
# ['Second Class' 'Standard Class' 'First Class' 'Same Day']

# %%
# Méthode d'expédition fréquement utilisée
shipping_mode = df['Ship Mode'].value_counts().reset_index()
shipping_mode = shipping_mode.rename(columns={'index':'Mode of shipment', 'Ship Mode': 'Use Frequency'})

print(shipping_mode)
# Out:
#   Mode of shipment  Use Frequency
# 0   Standard Class           5859
# 1     Second Class           1902
# 2      First Class           1501
# 3         Same Day            538

# %%
plt.pie(shipping_mode['Use Frequency'], labels=shipping_mode['Mode of shipment'], autopct ='%1.1f%%')

plt.title("Proportion of Mode of Shipment")

plt.show()

# %% [markdown]
# # Geographical Analysis

# %%
state = df['State'].value_counts().reset_index()
print(state.head(5))
# Out:
#           index  State
# 0    California   1946
# 1      New York   1097
# 2         Texas    973
# 3  Pennsylvania    582
# 4    Washington    504

# %%
# Here we rename our columns and display the number of customers by state
state = state.rename(columns = {'index': 'State', 'State':'Number of Customers'})
print(state.head(5))
# Out:
#           State  Number of Customers
# 0    California                 1946
# 1      New York                 1097
# 2         Texas                  973
# 3  Pennsylvania                  582
# 4    Washington                  504

# %%
print(state.head(7))
# Out:
#           State  Number of Customers
# 0    California                 1946
# 1      New York                 1097
# 2         Texas                  973
# 3  Pennsylvania                  582
# 4    Washington                  504
# 5      Illinois                  483
# 6          Ohio                  454

# %%
# Here we display the customer by city
city = df['City'].value_counts().reset_index()
print(city.head(5))
# Out:
#            index  City
# 0  New York City   891
# 1    Los Angeles   728
# 2   Philadelphia   532
# 3  San Francisco   500
# 4        Seattle   426

# %%
city = city.rename(columns={'index': 'City', 'City':'Number of customer'})
print(city.head(5))
# Out:
#             City  Number of customer
# 0  New York City                 891
# 1    Los Angeles                 728
# 2   Philadelphia                 532
# 3  San Francisco                 500
# 4        Seattle                 426

# %%
# Sales by state 
sales_by_state = df.groupby(['State'])['Sales'].sum().reset_index()
print(sales_by_state.sort_values(by='Sales', ascending=False).head(10).reset_index(drop=True))
# Out:
#           State        Sales
# 0    California  446306.4635
# 1      New York  306361.1470
# 2         Texas  168572.5322
# 3    Washington  135206.8500
# 4  Pennsylvania  116276.6500
# 5       Florida   88436.5320
# 6      Illinois   79236.5170
# 7      Michigan   76136.0740
# 8          Ohio   75130.3500
# 9      Virginia   70636.7200

# %%
# Sales by City
sales_by_state = df.groupby(['City'])['Sales'].sum().reset_index()
print(sales_by_state.sort_values(by='Sales', ascending=False).head(10).reset_index(drop=True))
# Out:
#             City        Sales
# 0  New York City  252462.5470
# 1    Los Angeles  173420.1810
# 2        Seattle  116106.3220
# 3  San Francisco  109041.1200
# 4   Philadelphia  108841.7490
# 5        Houston   63956.1428
# 6        Chicago   47820.1330
# 7      San Diego   47521.0290
# 8   Jacksonville   44713.1830
# 9        Detroit   42446.9440

# %% [markdown]
# # Product Analysis

# %%
print(df['Category'].unique())
# Out:
# ['Furniture' 'Office Supplies' 'Technology']

# %%
category = df['Category'].value_counts().reset_index()
category = category.rename(columns={'index':'Category', 'Category':'Total_category'})
print(category)
# Out:
#           Category  Total_category
# 0  Office Supplies            5909
# 1        Furniture            2078
# 2       Technology            1813

# %%
myexplose = [0.2, 0.1, 0]
plt.pie(category['Total_category'], labels=category['Category'], autopct ='%1.1f%%', explode=myexplose)
plt.title('Category of product')
plt.show()

# %%
# Group by number unique for each items of sub-category
sub_category_count = df.groupby(['Category'])['Sub-Category'].nunique().reset_index()
# La fonction nunique() retourne le nombre d'éléments uniques dans la colonne. 
#Ainsi, pour chaque catégorie, elle compte le nombre unique de sous-catégories.

print(sub_category_count.sort_values(by='Sub-Category', ascending=False).reset_index(drop=True))
# Out:
#           Category  Sub-Category
# 0  Office Supplies             9
# 1        Furniture             4
# 2       Technology             4

# %%
# Group category by sales
category_sales = df.groupby(['Category'])['Sales'].sum().reset_index()
print(category_sales.sort_values(by='Sales', ascending=False).reset_index(drop=True))
# Out:
#           Category        Sales
# 0       Technology  827455.8730
# 1        Furniture  728658.5757
# 2  Office Supplies  705422.3340

# %%
myexplode = [0.2, 0, 0]
plt.pie(category_sales['Sales'], labels=category_sales['Category'], 
        autopct ='%1.1f%%', explode = myexplode, shadow = True)
plt.title('Most sales Category')
plt.legend(title = 'Category')
plt.show()

# %% [markdown]
# #### Sales per product

# %%
cat_prod_sales = df.groupby(['Category', 'Sub-Category'])['Sales'].sum().reset_index()
cat_prod_sales_dataframe = cat_prod_sales.sort_values(by='Sales', 
                           ascending=False).reset_index(drop=True)
print(cat_prod_sales_dataframe)
# Out:
#            Category Sub-Category        Sales
# 0        Technology       Phones  327782.4480
# 1         Furniture       Chairs  322822.7310
# 2   Office Supplies      Storage  219343.3920
# 3         Furniture       Tables  202810.6280
# 4   Office Supplies      Binders  200028.7850
# 5        Technology     Machines  189238.6310
# 6        Technology  Accessories  164186.7000
# 7        Technology      Copiers  146248.0940
# 8         Furniture    Bookcases  113813.1987
# 9   Office Supplies   Appliances  104618.4030
# 10        Furniture  Furnishings   89212.0180
# 11  Office Supplies        Paper   76828.3040
# 12  Office Supplies     Supplies   46420.3080
# 13  Office Supplies          Art   26705.4100
# 14  Office Supplies    Envelopes   16128.0460
# 15  Office Supplies       Labels   12347.7260
# 16  Office Supplies    Fasteners    3001.9600

# %%
# group sub-category by sales
cat_prod_sales = df.groupby(['Sub-Category'])['Sales'].sum().reset_index()
cat_prod_sales_dataframe = cat_prod_sales.sort_values(by='Sales', 
                                   ascending=False).reset_index(drop=True)
print(cat_prod_sales_dataframe)
# Out:
#    Sub-Category        Sales
# 0        Phones  327782.4480
# 1        Chairs  322822.7310
# 2       Storage  219343.3920
# 3        Tables  202810.6280
# 4       Binders  200028.7850
# 5      Machines  189238.6310
# 6   Accessories  164186.7000
# 7       Copiers  146248.0940
# 8     Bookcases  113813.1987
# 9    Appliances  104618.4030
# 10  Furnishings   89212.0180
# 11        Paper   76828.3040
# 12     Supplies   46420.3080
# 13          Art   26705.4100
# 14    Envelopes   16128.0460
# 15       Labels   12347.7260
# 16    Fasteners    3001.9600

# %%
# traçons un giagramme à barres horizontales
x = cat_prod_sales_dataframe['Sub-Category']
y = cat_prod_sales_dataframe['Sales']

#Label
plt.title('Top product Sub-Categories based on sales')
plt.xlabel('Sales')
plt.ylabel('Sub-Category')
plt.barh(x, y)
plt.show()

# %%
# group sub-category by sales ascending order
cat_prod_sales_asc = df.groupby(['Sub-Category'])['Sales'].sum().reset_index()
cat_prod_sales_asc_dataframe = cat_prod_sales.sort_values(by='Sales', 
                                   ascending=True).reset_index(drop=True)
print(cat_prod_sales_asc_dataframe)
x = cat_prod_sales_asc_dataframe['Sub-Category']
y = cat_prod_sales_asc_dataframe['Sales']

#Label
plt.title('Top product Sub-Categories based on sales')
plt.xlabel('Sales')
plt.ylabel('Sub-Category')
plt.barh(x, y)
plt.show()
# Out:
#    Sub-Category        Sales
# 0     Fasteners    3001.9600
# 1        Labels   12347.7260
# 2     Envelopes   16128.0460
# 3           Art   26705.4100
# 4      Supplies   46420.3080
# 5         Paper   76828.3040
# 6   Furnishings   89212.0180
# 7    Appliances  104618.4030
# 8     Bookcases  113813.1987
# 9       Copiers  146248.0940
# 10  Accessories  164186.7000
# 11     Machines  189238.6310
# 12      Binders  200028.7850
# 13       Tables  202810.6280
# 14      Storage  219343.3920
# 15       Chairs  322822.7310
# 16       Phones  327782.4480

# %% [markdown]
# ## Sales

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
# Row ID           9800 non-null int64
# Order ID         9800 non-null object
# Order Date       9800 non-null object
# Ship Date        9800 non-null object
# Ship Mode        9800 non-null object
# Customer ID      9800 non-null object
# Customer Name    9800 non-null object
# Segment          9800 non-null object
# Country          9800 non-null object
# City             9800 non-null object
# State            9800 non-null object
# Postal Code      9789 non-null float64
# Region           9800 non-null object
# Product ID       9800 non-null object
# Category         9800 non-null object
# Sub-Category     9800 non-null object
# Product Name     9800 non-null object
# Sales            9800 non-null float64
# dtypes: float64(2), int64(1), object(15)
# memory usage: 1.3+ MB

# %%
date_columns = ['Ship Date', 'Order Date']
for x in date_columns:
    df[x] = pd.to_datetime(df[x], dayfirst=True)
    
# On utilise la boucle 'for' pour éviter d'utiliser le datetime() +sieurs fois

# df['Ship Date'] = pd.to_datetime(df['Ship Date'], dayfirst=True)
# df['Order Date'] = pd.to_datetime(df['Order Date'], dayfirst=True)
# 'dayfirst=True' indique à la fonction que le premier élément dans les dates est 
# le jour (par opposition au mois). En d'autres termes, cela spécifie que
#le format de date est de la forme 'jour/mois/année'.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
# Row ID           9800 non-null int64
# Order ID         9800 non-null object
# Order Date       9800 non-null datetime64[ns]
# Ship Date        9800 non-null datetime64[ns]
# Ship Mode        9800 non-null object
# Customer ID      9800 non-null object
# Customer Name    9800 non-null object
# Segment          9800 non-null object
# Country          9800 non-null object
# City             9800 non-null object
# State            9800 non-null object
# Postal Code      9789 non-null float64
# Region           9800 non-null object
# Product ID       9800 non-null object
# Category         9800 non-null object
# Sub-Category     9800 non-null object
# Product Name     9800 non-null object
# Sales            9800 non-null float64
# dtypes: datetime64[ns](2), float64(2), int64(1), object(13)
# memory usage: 1.3+ MB

# %%
# Group by year
year = df['Order Date'].dt.year.unique()
print(year)
# Out:
# [2017 2016 2015 2018]

# %%
# Group sum sales by year

# Group by year and summing the sales per year
sales_yearly = df.groupby(df['Order Date'].dt.year)['Sales'].sum()

# Setting new index and renamming the columns 
sales_yearly = sales_yearly.reset_index()
sales_yearly = sales_yearly.rename(columns={'index':'Order Date', 'Sales': 'Total_Year_Sales'})
print(sales_yearly.sort_values(by='Total_Year_Sales', ascending=False).reset_index(drop=True))
# Out:
#    Order Date  Total_Year_Sales
# 0        2018       722052.0192
# 1        2017       600192.5500
# 2        2015       479856.2081
# 3        2016       459436.0054

# %%
x = sales_yearly['Order Date']
y = sales_yearly['Total_Year_Sales']
plt.bar(x,y)

plt.title('Total sales per year')
plt.xlabel('Date')
plt.ylabel('Total_sales')

plt.xticks(rotation=65) # Les éléments sur x-axis auront une inclinaison de 65°
plt.show()

# %%
# plotting the line graph
plt.plot(sales_yearly['Order Date'], sales_yearly['Total_Year_Sales'], marker= 'o',
         ls='--', c = 'green', lw = '1.5')
# ls = linehstyle, c = color, lw = linewidth  on peut utiliser ces noms aussi
plt.title('Total sales per year')
plt.xlabel('Date')
plt.ylabel('Total_sales')

plt.xticks(rotation=65) # Les éléments sur x-axis auront une inclinaison de 65°
plt.show()

# %%
plt.plot(sales_yearly['Order Date'], sales_yearly['Total_Year_Sales'], 'o-.', 
         c = 'red')
# c = color, 'o-.' : signifie avoir des marqueurs en cercle et la ligne en tiret pointillés
plt.title('Total sales per year')
plt.xlabel('Date')
plt.ylabel('Total_sales')

plt.xticks(rotation=65) # Les éléments sur x-axis auront une inclinaison de 65°
plt.show()

# %% [markdown]
# ### Tendances des ventes trimestrielles : Quarterly Sales Trends
#
# ### For 2018

# %%
#Convert order date to datetime format
df['Order Date'] = pd.to_datetime(df['Order Date'], dayfirst=True)

# filter data cleaning to year
year_sales = df[df['Order Date'].dt.year == 2018]

#Calculate quarterly sales for year 2018
quarterly_sales = year_sales.resample('Q', on='Order Date')['Sales'].sum()

#Rename columns
quarterly_sales = quarterly_sales.reset_index()
quarterly_sales = quarterly_sales.rename(columns={'Order Date':'Quater', 'Sales':'Total Sales'})

print('This are the Quarterly sales for 2018')
print(quarterly_sales)

plt.plot(quarterly_sales['Quater'], quarterly_sales['Total Sales'], 'o-.', c = 'black')

plt.title('Total sales per Quater')
plt.xlabel('Date')
plt.ylabel('Total sales')

plt.xticks(rotation=65) # Les éléments sur x-axis auront une inclinaison de 65°
plt.show()
# Out:
# This are the Quarterly sales for 2018
#       Quater  Total Sales
# 0 2018-03-31  122260.8842
# 1 2018-06-30  127558.6200
# 2 2018-09-30  193815.8400
# 3 2018-12-31  278416.6750

# %% [markdown]
# #### Quater sales for 2017

# %%
#Convert order date to datetime format
df['Order Date'] = pd.to_datetime(df['Order Date'], dayfirst=True)

# filter data cleaning to year
year_sales = df[df['Order Date'].dt.year == 2017]

#Calculate quarterly sales for year 2017
quarterly_sales = year_sales.resample('Q', on='Order Date')['Sales'].sum()

#Rename columns
quarterly_sales = quarterly_sales.reset_index()
quarterly_sales = quarterly_sales.rename(columns={'Order Date':'Quater', 'Sales':'Total Sales'})

print('This are the Quarterly sales for 2017')
print(quarterly_sales)

plt.plot(quarterly_sales['Quater'], quarterly_sales['Total Sales'], 'o-.', c = 'b')

plt.title('Total sales per Quater')
plt.xlabel('Date')
plt.ylabel('Total sales')

plt.xticks(rotation=65) # Les éléments sur x-axis auront une inclinaison de 65°
plt.show()
# Out:
# This are the Quarterly sales for 2017
#       Quater  Total Sales
# 0 2017-03-31   92686.3650
# 1 2017-06-30  135061.1610
# 2 2017-09-30  138056.3742
# 3 2017-12-31  234388.6498

# %% [markdown]
# #### Quater sales for 2016

# %%
#Convert order date to datetime format
df['Order Date'] = pd.to_datetime(df['Order Date'], dayfirst=True)

# filter data cleaning to year
year_sales = df[df['Order Date'].dt.year == 2016]

#Calculate quarterly sales for year 2016
quarterly_sales = year_sales.resample('Q', on='Order Date')['Sales'].sum()

#Rename columns
quarterly_sales = quarterly_sales.reset_index()
quarterly_sales = quarterly_sales.rename(columns={'Order Date':'Quater', 'Sales':'Total Sales'})

print('This are the Quarterly sales for 2016')
print(quarterly_sales)

plt.plot(quarterly_sales['Quater'], quarterly_sales['Total Sales'], 'o-.', c = 'r')

plt.title('Total sales per Quater')
plt.xlabel('Date')
plt.ylabel('Total sales')

plt.xticks(rotation=65) # Les éléments sur x-axis auront une inclinaison de 65°
plt.show()
# Out:
# This are the Quarterly sales for 2016
#       Quater  Total Sales
# 0 2016-03-31   62357.6870
# 1 2016-06-30   87713.3730
# 2 2016-09-30  128560.2072
# 3 2016-12-31  180804.7382

# %%
#Convert order date to datetime format
df['Order Date'] = pd.to_datetime(df['Order Date'], dayfirst=True)

# filter data cleaning to year
year_sales = df[df['Order Date'].dt.year == 2015]

#Calculate quarterly sales for year 2015
quarterly_sales = year_sales.resample('Q', on='Order Date')['Sales'].sum()

#Rename columns
quarterly_sales = quarterly_sales.reset_index()
quarterly_sales = quarterly_sales.rename(columns={'Order Date':'Quater', 'Sales':'Total Sales'})

print('This are the Quarterly sales for 2015')
print(quarterly_sales)

plt.plot(quarterly_sales['Quater'], quarterly_sales['Total Sales'], 'o-.', c = 'green')

plt.title('Total sales per Quater')
plt.xlabel('Date')
plt.ylabel('Total sales')

plt.xticks(rotation=65) # Les éléments sur x-axis auront une inclinaison de 65°
plt.show()
# Out:
# This are the Quarterly sales for 2015
#       Quater  Total Sales
# 0 2015-03-31   73931.3960
# 1 2015-06-30   85874.0936
# 2 2015-09-30  142522.6063
# 3 2015-12-31  177528.1122

# %% [markdown]
# ### Tendances des ventes par mois
#
# ### For 2018's Months

# %%
#Convert order date to datetime format
df['Order Date'] = pd.to_datetime(df['Order Date'], dayfirst=True)

# filter data cleaning to year
year_sales_2018 = df[df['Order Date'].dt.year == 2018]

#Calculate quarterly sales for year 2018

monthly_sales_2018 = year_sales_2018.resample('M', on='Order Date')['Sales'].sum()

#Rename columns
monthly_sales_2018 = monthly_sales_2018.reset_index()
monthly_sales_2018 = monthly_sales_2018.rename(columns={'Order Date':'Month', 'Sales':'Total Montly Sales'})

print('This are the Quarterly sales for 2018')
print(monthly_sales_2018)

plt.plot(monthly_sales_2018['Month'], monthly_sales_2018['Total Montly Sales'], '-o', c = 'green')

plt.title('Total sales per Month')
plt.xlabel('Date')
plt.ylabel('Total sales')

plt.xticks(rotation=65) # Les éléments sur x-axis auront une inclinaison de 65°
plt.show()
# Out:
# This are the Quarterly sales for 2018
#         Month  Total Montly Sales
# 0  2018-01-31          43476.4740
# 1  2018-02-28          19920.9974
# 2  2018-03-31          58863.4128
# 3  2018-04-30          35541.9101
# 4  2018-05-31          43825.9822
# 5  2018-06-30          48190.7277
# 6  2018-07-31          44825.1040
# 7  2018-08-31          62837.8480
# 8  2018-09-30          86152.8880
# 9  2018-10-31          77448.1312
# 10 2018-11-30         117938.1550
# 11 2018-12-31          83030.3888

# %% [markdown]
# #### 2017 Months

# %%
#Convert order date to datetime format
df['Order Date'] = pd.to_datetime(df['Order Date'], dayfirst=True)

# filter data cleaning to year
year_sales_2017 = df[df['Order Date'].dt.year == 2017]

#Calculate quarterly sales for year 2018

monthly_sales_2017 = year_sales_2017.resample('M', on='Order Date')['Sales'].sum()

#Rename columns
monthly_sales_2017 = monthly_sales_2017.reset_index()
monthly_sales_2017 = monthly_sales_2017.rename(columns={'Order Date':'Month', 'Sales':'Total Montly Sales'})

print('This are the Quarterly sales for 2017')
print(monthly_sales_2017)

plt.plot(monthly_sales_2017['Month'], monthly_sales_2017['Total Montly Sales'], '-o', c = 'green')

plt.title('Total sales per Month')
plt.xlabel('Date')
plt.ylabel('Total sales')

plt.xticks(rotation=65) # Les éléments sur x-axis auront une inclinaison de 65°
plt.show()
# Out:
# This are the Quarterly sales for 2017
#         Month  Total Montly Sales
# 0  2017-01-31          18542.4910
# 1  2017-02-28          22978.8150
# 2  2017-03-31          51165.0590
# 3  2017-04-30          38679.7670
# 4  2017-05-31          56656.9080
# 5  2017-06-30          39724.4860
# 6  2017-07-31          38320.7830
# 7  2017-08-31          30542.2003
# 8  2017-09-30          69193.3909
# 9  2017-10-31          59583.0330
# 10 2017-11-30          79066.4958
# 11 2017-12-31          95739.1210

# %% [markdown]
# ### 2016 Months

# %%
#Convert order date to datetime format
df['Order Date'] = pd.to_datetime(df['Order Date'], dayfirst=True)

# filter data cleaning to year
year_sales_2016 = df[df['Order Date'].dt.year == 2016]

#Calculate quarterly sales for year 2018

monthly_sales_2016 = year_sales_2016.resample('M', on='Order Date')['Sales'].sum()

#Rename columns
monthly_sales_2016 = monthly_sales_2016.reset_index()
monthly_sales_2016 = monthly_sales_2016.rename(columns={'Order Date':'Month', 'Sales':'Total Montly Sales'})

print('This are the Quarterly sales for 2016')
print(monthly_sales_2016)

plt.plot(monthly_sales_2016['Month'], monthly_sales_2016['Total Montly Sales'], '-o', c = 'green')

plt.title('Total sales per Month')
plt.xlabel('Date')
plt.ylabel('Total sales')

plt.xticks(rotation=65) # Les éléments sur x-axis auront une inclinaison de 65°
plt.show()
# Out:
# This are the Quarterly sales for 2016
#         Month  Total Montly Sales
# 0  2016-01-31          18066.9576
# 1  2016-02-29          11951.4110
# 2  2016-03-31          32339.3184
# 3  2016-04-30          34154.4685
# 4  2016-05-31          29959.5305
# 5  2016-06-30          23599.3740
# 6  2016-07-31          28608.2590
# 7  2016-08-31          36818.3422
# 8  2016-09-30          63133.6060
# 9  2016-10-31          31011.7375
# 10 2016-11-30          75249.3995
# 11 2016-12-31          74543.6012

# %% [markdown]
# ### 2015 Months

# %%
#Convert order date to datetime format
df['Order Date'] = pd.to_datetime(df['Order Date'], dayfirst=True)

# filter data cleaning to year
year_sales_2015 = df[df['Order Date'].dt.year == 2015]

#Calculate quarterly sales for year 2018

monthly_sales_2015 = year_sales_2015.resample('M', on='Order Date')['Sales'].sum()

#Rename columns
monthly_sales_2015 = monthly_sales_2015.reset_index()
monthly_sales_2015 = monthly_sales_2015.rename(columns={'Order Date':'Month', 'Sales':'Total Montly Sales'})

print('This are the Quarterly sales for 2015')
print(monthly_sales_2015)

plt.plot(monthly_sales_2015['Month'], monthly_sales_2015['Total Montly Sales'], '-o', c = 'green')

plt.title('Total sales per Month')
plt.xlabel('Date')
plt.ylabel('Total sales')

plt.xticks(rotation=65) # Les éléments sur x-axis auront une inclinaison de 65°
plt.show()
# Out:
# This are the Quarterly sales for 2015
#         Month  Total Montly Sales
# 0  2015-01-31          14205.7070
# 1  2015-02-28           4519.8920
# 2  2015-03-31          55205.7970
# 3  2015-04-30          27906.8550
# 4  2015-05-31          23644.3030
# 5  2015-06-30          34322.9356
# 6  2015-07-31          33781.5430
# 7  2015-08-31          27117.5365
# 8  2015-09-30          81623.5268
# 9  2015-10-31          31453.3930
# 10 2015-11-30          77907.6607
# 11 2015-12-31          68167.0585
# C:\Users\user\Anaconda3\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
# ...
